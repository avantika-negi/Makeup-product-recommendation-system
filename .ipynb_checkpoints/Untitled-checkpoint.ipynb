# %% [markdown]
# # Makeup Product Recommendation System

# %%
import pandas as pd

# %% [markdown]
# #### Load the Dataset

# %%
df = pd.read_csv("most_used_beauty_cosmetics_products_extended.csv")

# %%
df.head(10)
# Out:
#         Product_Name              Brand        Category Usage_Frequency  \
# 0    Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 1     Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 2        Ultra Serum     Natasha Denona     Highlighter           Daily
# 3       Divine Serum        Ilia Beauty       Face Mask      Occasional
# 4   Super Foundation  Charlotte Tilbury     Highlighter      Occasional
# 5   Super Eye Shadow    Danessa Myricks      Foundation          Weekly
# 6    Super Lip Gloss           Bourjois          Powder         Monthly
# 7     Ultra Cleanser           Bourjois       Lip Gloss           Daily
# 8  Magic Highlighter       IT Cosmetics        CC Cream      Occasional
# 9    Perfect Bronzer       Fenty Beauty       Face Mask          Weekly
#
#    Price_USD  Rating  Number_of_Reviews Product_Size    Skin_Type  \
# 0      67.85     1.4                686         30ml    Sensitive
# ...

# %% [markdown]
# #### Understand the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product_Name       15000 non-null  object
#  1   Brand              15000 non-null  object
#  2   Category           15000 non-null  object
#  3   Usage_Frequency    15000 non-null  object
#  4   Price_USD          15000 non-null  float64
#  5   Rating             15000 non-null  float64
#  6   Number_of_Reviews  15000 non-null  int64
#  7   Product_Size       15000 non-null  object
#  8   Skin_Type          15000 non-null  object
#  9   Gender_Target      15000 non-null  object
#  10  Packaging_Type     15000 non-null  object
#  11  Main_Ingredient    15000 non-null  object
#  12  Cruelty_Free       15000 non-null  bool
#  13  Country_of_Origin  15000 non-null  object
#  14  Product_Type       15000 non-null  object
#  15  combined_features  15000 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Product_Name', 'Brand', 'Category', 'Usage_Frequency', 'Price_USD',
#        'Rating', 'Number_of_Reviews', 'Product_Size', 'Skin_Type',
#        'Gender_Target', 'Packaging_Type', 'Main_Ingredient', 'Cruelty_Free',
#        'Country_of_Origin', 'Product_Type'],
#       dtype='object')

# %%
df.shape
# Out:
# (15000, 15)

# %%
df.isnull().sum()
# Out:
# Product_Name         0
# Brand                0
# Category             0
# Usage_Frequency      0
# Price_USD            0
# Rating               0
# Number_of_Reviews    0
# Product_Size         0
# Skin_Type            0
# Gender_Target        0
# Packaging_Type       0
# Main_Ingredient      0
# Cruelty_Free         0
# Country_of_Origin    0
# Product_Type         0
# dtype: int64

# %% [markdown]
# #### Feature Engineering: Extract Product Type

# %%
def extract_product_type(name):
    name = name.lower()

    if "serum" in name:
        return "Serum"
    elif "lipstick" in name:
        return "Lipstick"
    elif "foundation" in name:
        return "Foundation"
    elif "mask" in name:
        return "Face Mask"
    elif "blush" in name:
        return "Blush"
    elif "highlighter" in name:
        return "Highlighter"
    elif "eye shadow" in name or "eyeshadow" in name:
        return "Eyeshadow"
    elif "mascara" in name:
        return "Mascara"
    elif "powder" in name:
        return "Powder"
    else:
        return "Other"

# %%
df["Product_Type"] = df["Product_Name"].apply(extract_product_type)

# %%
df[["Product_Name", "Product_Type"]].head()
# Out:
#        Product_Name Product_Type
# 0   Ultra Face Mask    Face Mask
# 1    Ultra Lipstick     Lipstick
# 2       Ultra Serum        Serum
# 3      Divine Serum        Serum
# 4  Super Foundation   Foundation

# %% [markdown]
# #### Prepare Features for Recommendation

# %%
#Select Features for Recommendation
df["combined_features"] = (
    df["Product_Type"].astype(str) + " " +
    df["Brand"].astype(str)
)

# %% [markdown]
# #### Text Vectorization using TF-IDF

# %%
#Convert Text → Numbers (TF-IDF)
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words="english")
tfidf_matrix = tfidf.fit_transform(df["combined_features"])

# %%
#check
tfidf_matrix.shape #{15000 = number of products,X = number of unique words (features)}
# Out:
# (15000, 67)

# %%
#Compute Cosine Similarity
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim.shape
# Out:
# (15000, 15000)

# %% [markdown]
# #### Build Recommendation Function

# %%
def recommend_products(product_name, price_range=10, top_n=5):

    idx = df[
        df["Product_Name"].str.lower().str.strip()
        == product_name.lower().strip()
    ].index

    if len(idx) == 0:
        return "Product not found"

    idx = idx[0]

    base_price = df.loc[idx, "Price_USD"]
    base_brand = df.loc[idx, "Brand"]
    base_type = df.loc[idx, "Product_Type"]

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    results = []

    for i, score in sim_scores:
        row = df.iloc[i]

        if (
            row["Brand"] != base_brand and
            row["Product_Type"] == base_type and
            abs(row["Price_USD"] - base_price) <= price_range
        ):
            results.append({
                "Product_Name": row["Product_Name"],
                "Brand": row["Brand"],
                "Price_USD": row["Price_USD"],
                "Product_Type": row["Product_Type"],
                "Similarity": round(score, 2)
            })

        if len(results) == top_n:
            break

    return results

# %% [markdown]
# ### Test the Recommendation System

# %%
recommend_products("Ultra Serum")
# Out:
# [{'Product_Name': 'Perfect Serum',
#   'Brand': 'IT Cosmetics',
#   'Price_USD': 95.74,
#   'Product_Type': 'Serum',
#   'Similarity': 0.38},
#  {'Product_Name': 'Perfect Serum',
#   'Brand': 'Make Up For Ever',
#   'Price_USD': 93.51,
#   'Product_Type': 'Serum',
#   'Similarity': 0.36},
#  {'Product_Name': 'Magic Serum',
#   'Brand': 'Make Up For Ever',
#   'Price_USD': 85.36,
#   'Product_Type': 'Serum',
#   'Similarity': 0.36},
#  {'Product_Name': 'Super Serum',
#   'Brand': 'Make Up For Ever',
#   'Price_USD': 92.82,
#   'Product_Type': 'Serum',
#   'Similarity': 0.36},
#  {'Product_Name': 'Divine Serum',
#   'Brand': 'Make Up For Ever',
#   'Price_USD': 94.17,
#   'Product_Type': 'Serum',
#   'Similarity': 0.36}]

# %%
recommend_products("Super Foundation")
# Out:
# [{'Product_Name': 'Divine Foundation',
#   'Brand': 'E.l.f.',
#   'Price_USD': 136.41,
#   'Product_Type': 'Foundation',
#   'Similarity': 0.53},
#  {'Product_Name': 'Super Foundation',
#   'Brand': 'IT Cosmetics',
#   'Price_USD': 140.17,
#   'Product_Type': 'Foundation',
#   'Similarity': 0.38},
#  {'Product_Name': 'Divine Foundation',
#   'Brand': 'IT Cosmetics',
#   'Price_USD': 145.28,
#   'Product_Type': 'Foundation',
#   'Similarity': 0.38},
#  {'Product_Name': 'Perfect Foundation',
#   'Brand': 'IT Cosmetics',
#   'Price_USD': 142.46,
#   'Product_Type': 'Foundation',
#   'Similarity': 0.38},
#  {'Product_Name': 'Magic Foundation',
#   'Brand': 'IT Cosmetics',
#   'Price_USD': 140.79,
#   'Product_Type': 'Foundation',
#   'Similarity': 0.38}]
